# %%
from pydantic import BaseModel

# %%
class User(BaseModel):
    id: int
    name: str
    is_active: bool = True

# %%
u = User(id="123", name="Thavan")

# %%
u
# Out:
# User(id=123, name='Thavan', is_active=True)

# %%
print(type(u.id), u.id)
# Out:
# <class 'int'> 123

# %%
 print(u.model_dump())
# Out:
# {'id': 123, 'name': 'Thavan', 'is_active': True}

# %%
from pydantic import BaseModel, ValidationError

# %%
class Product(BaseModel):
    name: str
    price: float
    in_stock: bool

# %%
try:
    p = Product(id="A1", price="free", in_stock="Yes")
except ValidationError as e:
    print(e)
# Out:
# 2 validation errors for Product
# name
#   Field required [type=missing, input_value={'id': 'A1', 'price': 'free', 'in_stock': 'Yes'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/missing
# price
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='free', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/float_parsing

# %%
from pydantic import BaseModel, Field, ValidationError

# %%
class Signup(BaseModel):
    username: str = Field(min_length=3, max_length=20)
    age: int = Field(ge=18, le=60)
    score: float = Field(default=0.0, ge=0.0, le=100.0)

# %%
try:
    S = Signup(username="jo", age=17, score=150.0)
except ValidationError as e:
    print(e)
# Out:
# 3 validation errors for Signup
# username
#   String should have at least 3 characters [type=string_too_short, input_value='jo', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_too_short
# age
#   Input should be greater than or equal to 18 [type=greater_than_equal, input_value=17, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.13/v/greater_than_equal
# score
#   Input should be less than or equal to 100 [type=less_than_equal, input_value=150.0, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.13/v/less_than_equal

# %%
from pydantic import BaseModel

# %%
class Address(BaseModel):
    street: str
    city: str
    pincode: int

# %%
class Customer(BaseModel):
    name: str
    email: str
    address: Address

# %%
payload = {
    "name": "Alice",
    "email": "alice@example.com",
    "address": {
        "street": "123 Main St",
        "city": "Anytown",
        "pincode": "12345"
    }
}

# %%
c = Customer(**payload)
print(c)
# Out:
# name='Alice' email='alice@example.com' address=Address(street='123 Main St', city='Anytown', pincode=12345)

# %%
print(c.address.pincode, type(c.address.pincode))
# Out:
# 12345 <class 'int'>
